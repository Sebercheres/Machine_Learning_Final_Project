# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Sebercheres/Machine_Learning_Final_Project/main/Dataset/water-potability.csv', index_col=0)

# %%
df
# Out:
#             ph    Hardness  ...  Turbidity  Potability
# 0          NaN  204.890455  ...   2.963135           0
# 1     3.716080  129.422921  ...   4.500656           0
# 2     8.099124  224.236259  ...   3.055934           0
# 3     8.316766  214.373394  ...   4.628771           0
# 4     9.092223  181.101509  ...   4.075075           0
# ...        ...         ...  ...        ...         ...
# 3271  4.668102  193.681735  ...   4.435821           1
# 3272  7.808856  193.553212  ...   2.798243           1
# 3273  9.419510  175.762646  ...   3.298875           1
# 3274  5.126763  230.603758  ...   4.708658           1
# 3275  7.874671  195.102299  ...   2.309149           1
#
# [3276 rows x 10 columns]

# %% [markdown]
# # Splitting the data

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Potability', axis=1)
y = df['Potability']

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, stratify=y, random_state=7)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Distribution

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
_ = X_train.hist(figsize=(20,15))

# %%
ax = sns.boxplot(x=X_train['ph'])

# %%
ax = sns.boxplot(x=X_train['Hardness'])

# %%
ax = sns.boxplot(x=X_train['Solids'])

# %%
ax = sns.boxplot(x=X_train['Chloramines'])

# %%
ax = sns.boxplot(x=X_train['Sulfate'])

# %%
ax = sns.boxplot(x=X_train['Conductivity'])

# %%
ax = sns.boxplot(x=X_train['Organic_carbon'])

# %%
ax = sns.boxplot(x=X_train['Trihalomethanes'])

# %%
ax = sns.boxplot(x=X_train['Turbidity'])

# %% [markdown]
# ## Data Correlation

# %%
df.dtypes
# Out:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(method='kendall'), annot=True)
plt.show()

# %%
def mean(x):
    return sum(x)/len(x)

def covariance(x,y):
    calc = []
    for i in range(len(x)):
        xi = x[i] - mean(x)
        yi = y[i] - mean(y)
        calc.append(xi * yi)
    return sum(calc)/(len(x) - 1)
    
a = [1,2,3,4,5] ; b = [5,4,3,2,1]
print(covariance(a,b))
# Out:
# -2.5

# %%
ax = sns.scatterplot(x="ph", y="Turbidity", hue=df.Potability,data=df)

# %%
ax = sns.scatterplot(x="ph", y="Sulfate", hue=df.Potability,data=df)

# %%
ax = sns.scatterplot(x="ph", y="Conductivity", hue=df.Potability,data=df)

# %%
ax = sns.scatterplot(x="ph", y="Organic_carbon", hue=df.Potability,data=df)

# %%
ax = sns.scatterplot(x="ph", y="Trihalomethanes", hue=df.Potability,data=df)

# %%
ax = sns.scatterplot(x="ph", y="Hardness", hue=df.Potability,data=df)

# %%
ax = sns.scatterplot(x="ph", y="Chloramines", hue=df.Potability,data=df)

# %%
df.corr().abs()['Potability'].sort_values(ascending = False)
# Out:
# Potability         1.000000
# Solids             0.033743
# Organic_carbon     0.030001
# Chloramines        0.023779
# Sulfate            0.023577
# Hardness           0.013837
# Conductivity       0.008128
# Trihalomethanes    0.007130
# ph                 0.003556
# Turbidity          0.001581
# Name: Potability, dtype: float64

# %% [markdown]
# ## Identify missing value, outlier, anomaly, duplicates

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})

plt.show()

# %%
df.describe()
# Out:
#                 ph     Hardness  ...    Turbidity   Potability
# count  2785.000000  3276.000000  ...  3276.000000  3276.000000
# mean      7.080795   196.369496  ...     3.966786     0.390110
# std       1.594320    32.879761  ...     0.780382     0.487849
# min       0.000000    47.432000  ...     1.450000     0.000000
# 25%       6.093092   176.850538  ...     3.439711     0.000000
# 50%       7.036752   196.967627  ...     3.955028     0.000000
# 75%       8.062066   216.667456  ...     4.500320     1.000000
# max      14.000000   323.124000  ...     6.739000     1.000000
#
# [8 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df[df['Potability']==0].describe()
# Out:
#                 ph     Hardness  ...    Turbidity  Potability
# count  1684.000000  1998.000000  ...  1998.000000      1998.0
# mean      7.085378   196.733292  ...     3.965800         0.0
# std       1.683499    31.057540  ...     0.780282         0.0
# min       0.000000    98.452931  ...     1.450000         0.0
# 25%       6.037723   177.823265  ...     3.444062         0.0
# 50%       7.035456   197.123423  ...     3.948076         0.0
# 75%       8.155510   216.120687  ...     4.496106         0.0
# max      14.000000   304.235912  ...     6.739000         0.0
#
# [8 rows x 10 columns]

# %%
df[df['Potability']==1].describe()
# Out:
#                 ph     Hardness  ...    Turbidity  Potability
# count  1101.000000  1278.000000  ...  1278.000000      1278.0
# mean      7.073783   195.800744  ...     3.968328         1.0
# std       1.448048    35.547041  ...     0.780842         0.0
# min       0.227499    47.432000  ...     1.492207         1.0
# 25%       6.179312   174.330531  ...     3.430909         1.0
# 50%       7.036752   196.632907  ...     3.958576         1.0
# 75%       7.933068   218.003420  ...     4.509569         1.0
# max      13.175402   323.124000  ...     6.494249         1.0
#
# [8 rows x 10 columns]
